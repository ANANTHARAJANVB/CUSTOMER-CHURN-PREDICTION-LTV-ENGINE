# %%
from fastapi import FastAPI

# %%
app = FastAPI()

# %%
@app.get("/")
def home():
    return {"message": "Customer Churn API Running Successfully"}

# %%
home()
# Out:
# {'message': 'Customer Churn API Running Successfully'}

# %%
app

# %% [markdown]
# # Day 20 – FastAPI Setup & Basic API
#
# ### Tasks Completed
# - Installed FastAPI
# - Imported FastAPI
# - Created FastAPI application
# - Created Home Endpoint
# - Tested API response
#
# ### Result
# Successfully created a basic FastAPI application for Customer Churn Prediction.
