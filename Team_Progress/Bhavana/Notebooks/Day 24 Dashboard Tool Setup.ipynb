# %% [markdown]
# # Day 24 - Dashboard Tool Setup
#
# Objective:
# Connect PostgreSQL database with Metabase for dashboard development.

# %% [markdown]
# Tasks Completed
#
# 1. Installed Metabase.
# 2. Started Metabase using Java.
# 3. Created PostgreSQL database (telco_churn_db).
# 4. Connected Metabase with PostgreSQL.
# 5. Verified successful connection.

# %% [markdown]
# Connection Details
#
# Database: telco_churn_db
# Host: localhost
# Port: 5432
# Tool: Metabase
# Status: Connected Successfully
