# %%
# DAY 3 
# Loading Dataset Path
#The file_path variable stores the location of the Telco Customer Churn dataset for loading into the project.

import pandas as pd
import numpy as np

# %%
# Reading Dataset
file_path = r"C:\Users\user\OneDrive\Desktop\ZAALIMA PROJECT\CUSTOMER CHURN PREDICTION LTV ENGINE\data\raw\Telco-Customer-Churn.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 688   0946-FKYTX    Male              0      No         No      52
# 12    8091-TTVAX    Male              0     Yes         No      58
# 4112  6627-CFOSN  Female              0      No         No      59
# 1324  0031-PVLZI  Female              0     Yes        Yes       4
# 714   4312-KFRXN    Male              0     Yes         No      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 688            No  No phone service             DSL                   No  ...
# 12            Yes               Yes     Fiber optic                   No  ...
# 4112          Yes               Yes     Fiber optic                  Yes  ...
# 1324          Yes                No              No  No internet service  ...
# 714           Yes               Yes              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include='object')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22508\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
# ...

# %% [markdown]
# #INITIAL DATASET OBSERVATIONS
# 1. Dataset contains customer demographic and service usage information.
# 2. Both numerical and categorical columns are present.
# 3. Some columns may require datatype conversion.
# 4. Target column is:
#    - Churn
# 5. customerID acts as unique identifier.
# 6. TotalCharges may require datatype cleaning.

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

numerical_columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='str')

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

categorical_columns
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22508\3659052312.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include=['object']).columns
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='str')

# %%
print("Number of Numerical Columns:", len(numerical_columns))
print("Number of Categorical Columns:", len(categorical_columns))
# Out:
# Number of Numerical Columns: 3
# Number of Categorical Columns: 18

# %% [markdown]
# # Key Observations — DAY 3 (Basic Data Understanding & Initial Profiling)
#
# ## 1. Dataset Structure
# - The dataset contains customer-related information for churn prediction analysis.
# - Total rows and columns were successfully identified using `df.shape`.
# - Dataset includes demographic details, subscription services, billing information, and churn status.
#
# ---
#
# ## 2. Column Analysis
# - The dataset contains both numerical and categorical features.
# - `customerID` acts as a unique identifier column.
# - `Churn` is identified as the target variable for prediction.
#
# ---
#
# ## 3. Numerical Features Identified
# The following columns were identified as numerical:
# - SeniorCitizen
# - tenure
# - MonthlyCharges
#
# Some numerical columns may require further preprocessing and scaling during later stages.
#
# ---
#
# ## 4. Categorical Features Identified
# Most columns in the dataset are categorical in nature, including:
# - gender
# - Partner
# - Dependents
# - InternetService
# - Contract
# - PaymentMethod
# - Churn
#
# These columns may later require encoding techniques for machine learning models.
#
# ---
#
# ## 5. Datatype Observations
# - Most categorical columns are stored as `object` datatype.
# - Numerical columns are stored as `int64` and `float64`.
# - `TotalCharges` may require datatype conversion after checking for blank spaces or invalid values.
#
# ---
#
# ## 6. Dataset Quality Initial Findings
# - Initial inspection showed the dataset is structured properly.
# - Further checks are required for:
#   - Missing values
#   - Blank spaces
#   - Duplicate records
#   - Data inconsistencies
#
# These validations will be performed in upcoming EDA stages.
#
# ---
#
# ## 7. Statistical Understanding
# - `df.describe()` provided statistical summaries for numerical columns.
# - `df.describe(include='object')` helped identify:
#   - Unique category counts
#   - Most frequent categories
#   - Frequency distributions
#
# This helps understand customer behavior patterns at an early stage.
#
# ---
#
# ## 8. Overall Conclusion
# - The dataset is suitable for churn prediction analysis.
# - Initial profiling has been completed successfully.
# - The dataset now requires detailed data cleaning and preprocessing before feature engineering and model training.
