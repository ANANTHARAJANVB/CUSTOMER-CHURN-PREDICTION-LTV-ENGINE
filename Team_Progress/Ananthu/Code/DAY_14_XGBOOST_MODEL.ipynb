# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

from xgboost import XGBClassifier

import matplotlib.pyplot as plt
import seaborn as sns

import joblib

df = pd.read_csv(
 r"C:\Users\user\OneDrive\Desktop\ZAALIMA PROJECT\CUSTOMER CHURN PREDICTION LTV ENGINE\data\processed\telco_churn_encoded_day13.csv"
)

# %%
# Separate Features & Target
X = df.drop(
    columns=["Churn"]
)

y = df["Churn"]

# %%
#Train Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
#Verify Split next 4 steps
X_train.shape
# Out:
# (5634, 45)

# %%
X_test.shape
# Out:
# (1409, 45)

# %%
y_train.value_counts(normalize=True)
# Out:
# Churn
# 0    0.734647
# 1    0.265353
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# Churn
# 0    0.734564
# 1    0.265436
# Name: proportion, dtype: float64

# %%
#create xgboost model
xgb_model = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# %%
xgb_model.fit(
    X_train,
    y_train
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
#predictions
y_pred = xgb_model.predict(
    X_test
)

# %%
#accuracy
accuracy = accuracy_score(
    y_test,
    y_pred
)

accuracy
# Out:
# 0.7899219304471257

# %%
precision = precision_score(
    y_test,
    y_pred
)

precision
# Out:
# 0.6274509803921569

# %%
recall = recall_score(
    y_test,
    y_pred
)

recall
# Out:
# 0.5133689839572193

# %%
f1 = f1_score(
    y_test,
    y_pred
)

f1
# Out:
# 0.5647058823529412

# %%
print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1035
#            1       0.63      0.51      0.56       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.70      0.71      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
cm = confusion_matrix(
    y_test,
    y_pred
)

cm
# Out:
# array([[921, 114],
#        [182, 192]])

# %%
plt.figure(figsize=(6,4))

sns.heatmap(
    cm,
    annot=True,
    fmt="d"
)

plt.title("XGBoost Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %%
importance_df = pd.DataFrame({
    "Feature": X.columns,
    "Importance": xgb_model.feature_importances_
})

# %%
importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df.head(20)
# Out:
#                                Feature  Importance
# 8                ContractSecurityScore    0.206969
# 31                   Contract_Two year    0.192381
# 16         InternetService_Fiber optic    0.149948
# 17                  InternetService_No    0.050831
# 18  OnlineSecurity_No internet service    0.042049
# 1                               tenure    0.015515
# 13                    PhoneService_Yes    0.015177
# 34      PaymentMethod_Electronic check    0.015085
# 27                     StreamingTV_Yes    0.015011
# 29                 StreamingMovies_Yes    0.014972
# 19                  OnlineSecurity_Yes    0.014938
# 30                   Contract_One year    0.013721
# 15                   MultipleLines_Yes    0.013303
# 43        MonthlyChargeCategory_Medium    0.013274
# 25                     TechSupport_Yes    0.012926
# 7                    RevenueEfficiency    0.012455
# 14      MultipleLines_No phone service    0.012228
# ...

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=importance_df.head(15),
    x="Importance",
    y="Feature"
)

plt.title(
    "Top 15 Important Features"
)

plt.show()

# %%
importance_df.to_csv(
    "../../models/artifacts/xgboost_feature_importance.csv",
    index=False
)

# %%
import pandas as pd
df.to_csv("../../data/processed/telco_churn_xgboost.csv", index=False)
