# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../data/raw/WA_Fn-UseC_-Telco-Customer-Churn (1).csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
sns.countplot(x="Churn", data=df)

plt.title("Churn Distribution")

plt.show()

# %% [markdown]
# ### Observation
#
# Most customers stayed with the company, but a significant number of customers also churned.

# %%
sns.countplot(
    x="gender",
    hue="Churn",
    data=df
)

plt.title("Gender vs Churn")

plt.show()

# %% [markdown]
# ### Observation
#
# Gender does not appear to strongly affect customer churn behavior.

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    x="SeniorCitizen",
    hue="Churn",
    data=df
)

plt.title("Senior Citizen vs Churn")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x="InternetService",
    hue="Churn",
    data=df
)

plt.title("Internet Service vs Churn")


plt.show()

# %% [markdown]
# ### Observation
#
# Fiber Optic internet users appear to have higher churn rates compared to DSL users.

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    x="PaymentMethod",
    hue="Churn",
    data=df
)

plt.xticks(rotation=20)

plt.title("Payment Method vs Churn")


plt.show()

# %% [markdown]
# ### Observation
#
# Customers using electronic check payment methods show higher churn behavior.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Churn",
    y="MonthlyCharges",
    data=df
)

plt.title("Monthly Charges vs Churn")



plt.show()

# %% [markdown]
# ### Observation
#
# Customers with higher monthly charges are more likely to churn.

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x="MonthlyCharges",
    hue="Churn",
    kde=True
)

plt.title("Monthly Charges Distribution by Churn")


plt.show()

# %% [markdown]
# ### Observation
#
# Most customers stayed with the company, but a significant number of customers also churned.
